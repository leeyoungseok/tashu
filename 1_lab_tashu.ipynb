# %% [markdown]
# <a href="https://colab.research.google.com/github/leeyoungseok/tashu/blob/main/1_lab_tashu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 타슈 데이터 날짜/요일별/정거장 살펴보기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/MyDrive/교과목강의-실습-교재/2023-교육대학원-빅데이터/실습/01 - tashu/data/sample_rent.csv')

train.head(5)
# Out:
#    STATION  YEAR  MONTH  DAY  HOUR  WEEKDAY  SEASON  TEMPERATURE  RAINFALL  \
# 0        1  2013      1    1     0        1       3         -8.8       0.0
# 1        1  2013      1    1     1        1       3         -8.5       0.0
# 2        1  2013      1    1     2        1       3         -8.5       0.0
# 3        1  2013      1    1     3        1       3         -9.0       0.0
# 4        1  2013      1    1     4        1       3         -9.1       0.0
#
#    WINDSPEED  HUMLDITY  SNOWFALL  RENTCOUNT
# 0        0.1      90.0       8.8        0.0
# 1        0.9      90.0       8.8        0.0
# 2        1.0      89.0       8.8        0.0
# 3        0.7      91.0       8.8        0.0
# 4        0.6      92.0       8.8        0.0

# %%
train.info
# Out:
# <bound method DataFrame.info of          STATION  YEAR  MONTH  DAY  HOUR  WEEKDAY  SEASON  TEMPERATURE  \
# 0              1  2013      1    1     0        1       3         -8.8
# 1              1  2013      1    1     1        1       3         -8.5
# 2              1  2013      1    1     2        1       3         -8.5
# 3              1  2013      1    1     3        1       3         -9.0
# 4              1  2013      1    1     4        1       3         -9.1
# ...          ...   ...    ...  ...   ...      ...     ...          ...
# 1261435      144  2013     12   31    19        1       3          5.8
# 1261436      144  2013     12   31    20        1       3          5.9
# 1261437      144  2013     12   31    21        1       3          5.6
# 1261438      144  2013     12   31    22        1       3          5.2
# 1261439      144  2013     12   31    23        1       3          4.8
#
#          RAINFALL  WINDSPEED  HUMLDITY  SNOWFALL  RENTCOUNT
# 0             0.0        0.1      90.0       8.8        0.0
# 1             0.0        0.9      90.0       8.8        0.0
# 2             0.0        1.0      89.0       8.8        0.0
# 3             0.0        0.7      91.0       8.8        0.0
# 4             0.0        0.6      92.0       8.8        0.0
# ...           ...        ...       ...       ...        ...
# 1261435       0.0        1.8      73.0       0.0        0.0
# 1261436       0.0        1.7      74.0       0.0        0.0
# 1261437       0.0        2.7      72.0       0.0        0.0
# 1261438       0.0        2.2      76.0       0.0        0.0
# 1261439       0.0        2.5      77.0       0.0        0.0
#
# [1261440 rows x 13 columns]>

# %%
station_df = pd.read_csv('/content/drive/MyDrive/교과목강의-실습-교재/2023-교육대학원-빅데이터/실습/01 - tashu/data/station.csv')
station_df.head(5)
# Out:
#    번호  키오스크번호   구별                  명칭                         위치  \
# 0   1       1  유성구    무역전시관입구(택시승강장 앞)                  엑스포다리 맞은편
# 1   2       2  유성구          대전컨벤션 센터 앞                   둔산대교 맞은편
# 2   3       3   서구         한밭수목원(정문입구)                    한밭수목원 내
# 3   4       4   서구  초원아파트104동부근(버스정류장)  초원아파트 104동앞 쪽문 육교 버스정류장 앞
# 4   5       5   서구     둔산대공원 입구(버스정류장)  한밭수목원에서 평송수련원 가는길 버스정류장 앞
#
#                 주소  거치대                    좌표
# 0      유성구 도룡동 3-8   14  36.374325,127.387462
# 1     유성구 도룡동 4-19   20  36.374472,127.392241
# 2       서구 만년동 396   19  36.369855,127.388749
# 3       서구 만년동 401   12  36.368192,127.379281
# 4   서구 둔산동 1521-10   13  36.365034,127.389361

# %%
train.describe()
# Out:
#             STATION       YEAR         MONTH           DAY          HOUR  \
# count  1.261440e+06  1261440.0  1.261440e+06  1.261440e+06  1.261440e+06
# mean   7.250000e+01     2013.0  6.526027e+00  1.572055e+01  1.150000e+01
# std    4.156823e+01        0.0  3.447853e+00  8.796250e+00  6.922189e+00
# min    1.000000e+00     2013.0  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    3.675000e+01     2013.0  4.000000e+00  8.000000e+00  5.750000e+00
# 50%    7.250000e+01     2013.0  7.000000e+00  1.600000e+01  1.150000e+01
# 75%    1.082500e+02     2013.0  1.000000e+01  2.300000e+01  1.725000e+01
# max    1.440000e+02     2013.0  1.200000e+01  3.100000e+01  2.300000e+01
#
#             WEEKDAY        SEASON   TEMPERATURE      RAINFALL     WINDSPEED  \
# count  1.261440e+06  1.261440e+06  1.261440e+06  1.261440e+06  1.261440e+06
# mean   2.994521e+00  1.490411e+00  1.312479e+01  1.278767e-01  1.575057e+00
# std    1.999993e+00  1.116767e+00  1.132480e+01  9.294803e-01  1.078129e+00
# min    0.000000e+00  0.000000e+00 -1.650000e+01  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  0.000000e+00  3.300000e+00  0.000000e+00  8.000000e-01
# 50%    3.000000e+00  1.000000e+00  1.340000e+01  0.000000e+00  1.300000e+00
# 75%    5.000000e+00  2.000000e+00  2.340000e+01  0.000000e+00  2.100000e+00
# max    6.000000e+00  3.000000e+00  3.490000e+01  2.870000e+01  7.700000e+00
#
#            HUMLDITY      SNOWFALL     RENTCOUNT
# count  1.261440e+06  1.261440e+06  1.261440e+06
# mean   7.296952e+01  5.778881e-01  8.209356e-01
# std    1.995988e+01  2.442430e+00  2.338449e+00
# min    1.300000e+01  0.000000e+00  0.000000e+00
# 25%    6.000000e+01  0.000000e+00  0.000000e+00
# 50%    7.600000e+01  0.000000e+00  0.000000e+00
# 75%    9.000000e+01  0.000000e+00  1.000000e+00
# max    1.000000e+02  1.840000e+01  1.080000e+02

# %%
train.groupby(['STATION'])['RENTCOUNT'].sum().nlargest(10)
# Out:
# STATION
# 3     55294.0
# 56    34038.0
# 17    29633.0
# 31    28865.0
# 33    25506.0
# 32    24668.0
# 14    20744.0
# 60    19330.0
# 55    19058.0
# 8     18702.0
# Name: RENTCOUNT, dtype: float64

# %%
group_season = train.groupby(['SEASON'])['RENTCOUNT'].sum().reset_index()
ax = sns.barplot(x=group_season['SEASON'], y=group_season['RENTCOUNT'])
ax.set(xlabel='Season', ylabel='Rent count')
season = ['Spring', 'Summer', 'Fall', 'Winter']
plt.xticks(np.arange(4), season)
plt.title('The number of rented bike by season')
plt.show()

# %%
group_weekday = train.groupby(['WEEKDAY'])['RENTCOUNT'].sum().reset_index()
ax = sns.barplot(x=group_weekday['WEEKDAY'],
                 y=group_weekday['RENTCOUNT'])
ax.set(xlabel='Weekday', ylabel='Count')
weekday = ['SUN', 'MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT']
plt.xticks(np.arange(7), weekday)
plt.title('The number of rented bike by weekday')
plt.show()

# %%
group_mn = train.groupby(['MONTH'])['RENTCOUNT'].sum().reset_index()
ax = sns.barplot(x=group_mn['MONTH'], y=group_mn['RENTCOUNT'])
ax.set(xlabel='Month', ylabel='count')
plt.title('The number of rented bike by weekday')
plt.show()

# %%
group_hr = train.groupby(['HOUR'])['RENTCOUNT'].sum().reset_index()
ax = sns.barplot(x=group_hr['HOUR'],
                 y=group_hr['RENTCOUNT'])
ax.set(xlabel='Hour', ylabel='Count')
plt.title('The number of rented bike by weekday')
plt.show()

# %%
plt.figure(figsize=(10,6))
station_3 = train[train['STATION']==3]
group_weekday_hour = station_3.groupby(['WEEKDAY','HOUR'])['RENTCOUNT'].mean().reset_index()
weekday_hour = np.zeros([7, 24])
for i in range(7*24):
    weekday_hour[int(group_weekday_hour.iloc[i][0])][int(group_weekday_hour.iloc[i][1])]=group_weekday_hour.iloc[i][2]
ax = sns.heatmap(weekday_hour, cmap="YlGnBu")
ax.set(xlabel='Hour', ylabel='Weekday')
weekday = ['SUN', 'MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT']
plt.yticks(np.arange(7), weekday)
plt.show()

# %%
station_lat = []
station_lon = []

for station in range(0,144):
    station_lat.append(station_df.iloc[station][-1].split(',')[0])
    station_lon.append(station_df.iloc[station][-1].split(',')[1])

# %%
top10_lat = []
top10_lon = []

for top in train.groupby(['STATION'])['RENTCOUNT'].sum().nlargest(10).index:
    top10_lat.append(float(station_lat[top]))
    top10_lon.append(float(station_lon[top]))

# %%
import folium
# %matplotlib inline

# %%
locationlist = list(zip(top10_lat, top10_lon))
locationlist
# Out:
# [(36.368192, 127.379281),
#  (36.357928, 127.342792),
#  (36.351132, 127.384838),
#  (36.359293, 127.354503),
#  (36.357889, 127.365972),
#  (36.358494, 127.361197),
#  (36.355591, 127.390063),
#  (36.35213, 127.346011),
#  (36.361736, 127.344994),
#  (36.361392, 127.374236)]

# %%
top10_lat
# Out:
# [36.368192,
#  36.357928,
#  36.351132,
#  36.359293,
#  36.357889,
#  36.358494,
#  36.355591,
#  36.35213,
#  36.361736,
#  36.361392]

# %%
map = folium.Map(location=[top10_lat[0], top10_lon[0]], zoom_start=13)
for point in range(10):
    folium.Marker(locationlist[point], popup=locationlist[point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d622050edf767258145ffe203da5fca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d622050edf767258145ffe203da5fca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d622050edf767258145ffe203da5fca = L.map(
#                 &quot;map_8d622050edf767258145ffe203da5fca&quot;,
#                 {
#                     center: [36.368192, 127.379281],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_061593ffd381486426bf1a484deef341 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8d622050edf767258145ffe203da5fca);
#
#
#             var marker_986e1ed4d65c7c0218c1581dff460288 = L.marker(
#                 [36.368192, 127.379281],
#                 {}
#             ).addTo(map_8d622050edf767258145ffe203da5fca);
#
#
#         var popup_ea6b9c3155366b0ceb7d3155e11c2960 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68af740f04b9bff792293610ad3529f8 = $(`&lt;div id=&quot;html_68af740f04b9bff792293610ad3529f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(36.368192, 127.379281)&lt;/div&gt;`)[0];
#                 popup_ea6b9c3155366b0ceb7d3155e11c2960.setContent(html_68af740f04b9bff792293610ad3529f8);
#
#
#
#         marker_986e1ed4d65c7c0218c1581dff460288.bindPopup(popup_ea6b9c3155366b0ceb7d3155e11c2960)
#         ;
#
#
#
#
#             var marker_d6abf6f27c7baeef55b939f9e3372620 = L.marker(
#                 [36.357928, 127.342792],
#                 {}
#             ).addTo(map_8d622050edf767258145ffe203da5fca);
#
#
#         var popup_64e47931655f59dd495f8888b86bc637 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_366ddd874479ae27244762c9f0b2975e = $(`&lt;div id=&quot;html_366ddd874479ae27244762c9f0b2975e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(36.357928, 127.342792)&lt;/div&gt;`)[0];
#                 popup_64e47931655f59dd495f8888b86bc637.setContent(html_366ddd874479ae27244762c9f0b2975e);
#
#
#
#         marker_d6abf6f27c7baeef55b939f9e3372620.bindPopup(popup_64e47931655f59dd495f8888b86bc637)
#         ;
#
#
#
#
#             var marker_ab2f9535f1d1ba9b903122b15f14f52e = L.marker(
#                 [36.351132, 127.384838],
#                 {}
#             ).addTo(map_8d622050edf767258145ffe203da5fca);
#
#
#         var popup_9833859626dcdc187699551e461fb44e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff4801c18d6c07260761b6a7a1396102 = $(`&lt;div id=&quot;html_ff4801c18d6c07260761b6a7a1396102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(36.351132, 127.384838)&lt;/div&gt;`)[0];
#                 popup_9833859626dcdc187699551e461fb44e.setContent(html_ff4801c18d6c07260761b6a7a1396102);
#
#
#
#         marker_ab2f9535f1d1ba9b903122b15f14f52e.bindPopup(popup_9833859626dcdc187699551e461fb44e)
#         ;
#
#
#
#
#             var marker_faf8116d4a472b906b690f4943b76e58 = L.marker(
#                 [36.359293, 127.354503],
#                 {}
#             ).addTo(map_8d622050edf767258145ffe203da5fca);
#
#
#         var popup_f26ae388f1eb117f86bce725c08ed14a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a6c0907ddb95ed62253e7e55fe80fa71 = $(`&lt;div id=&quot;html_a6c0907ddb95ed62253e7e55fe80fa71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(36.359293, 127.354503)&lt;/div&gt;`)[0];
#                 popup_f26ae388f1eb117f86bce725c08ed14a.setContent(html_a6c0907ddb95ed62253e7e55fe80fa71);
#
#
#
#         marker_faf8116d4a472b906b690f4943b76e58.bindPopup(popup_f26ae388f1eb117f86bce725c08ed14a)
#         ;
#
#
#
#
#             var marker_2ec8b28a02492130b57c1456057dbcf9 = L.marker(
#                 [36.357889, 127.365972],
#                 {}
#             ).addTo(map_8d622050edf767258145ffe203da5fca);
#
#
#         var popup_6a5549b34c4ed9e5eaea6afed7e24ca7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff5bf586e4d1722c5b1b3dc86dcb5ced = $(`&lt;div id=&quot;html_ff5bf586e4d1722c5b1b3dc86dcb5ced&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(36.357889, 127.365972)&lt;/div&gt;`)[0];
#                 popup_6a5549b34c4ed9e5eaea6afed7e24ca7.setContent(html_ff5bf586e4d1722c5b1b3dc86dcb5ced);
#
#
#
#         marker_2ec8b28a02492130b57c1456057dbcf9.bindPopup(popup_6a5549b34c4ed9e5eaea6afed7e24ca7)
#         ;
#
#
#
#
#             var marker_c3487e87eb9e3d7651334747a63fdc5b = L.marker(
